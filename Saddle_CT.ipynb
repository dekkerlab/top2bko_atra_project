# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.gridspec as gridspec
import bbi
import bioframe
import matplotlib as mpl
import CentTeltrack as CT
# make matplotlib pdf-s text recognizable by evil-Adobe
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import cooltools

# %%
fls = ['BKO98-ATRA-5days-4-51-and-4-52-R1R2','BKO98-Ctrl-4-51-and-4-52-R1R2',
       'WT-ATRA-5days-4-51-and-4-52-R1R2','WT-Ctrl-4-51-and-4-52-R1R2']

# %%
#trans expected (long and short also done here)
i=1
for fn in fls[:-1]:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools expected-trans " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms22.tsv \
         -o Trans-Expected-arms/"+n+"_100kb.trans.tsv"
    cmd2 = "cooltools expected-trans " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms-long.tsv \
         -o Trans-Expected-arms/"+n+"_100kb_long.trans.tsv"
    cmd3 = "cooltools expected-trans " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms-short.tsv \
         -o Trans-Expected-arms/"+n+"_100kb_short.trans.tsv"

    print(n)
    #print(cmd1)
    os.system(cmd1)
    #os.system(cmd2)
    #os.system(cmd3)
    #print(cmd1,"\n",cmd2)
    print("Done\t",n,i)
    i=i+1

# %%
#cis expected by arms (long and short also done here)
i=1
for fn in fls:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools expected-cis " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms22.tsv \
         -o Cis-Expected-arms/"+n+"_100kb.cis.tsv"
    cmd2 = "cooltools expected-cis " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms-long.tsv \
         -o Cis-Expected-arms/"+n+"_100kb_long.cis.tsv"
    cmd3 = "cooltools expected-cis " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms-short.tsv \
         -o Cis-Expected-arms/"+n+"_100kb_short.cis.tsv"

    print(n)
    #print(cmd1)
    os.system(cmd1)
    os.system(cmd2)
    os.system(cmd3)
    #print(cmd1,"\n",cmd2)
    print("Done\t",n,i)
    i=i+1

# %%
#cis expected whole chromosome (long and short also done here)
i=1
for fn in fls:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools expected-cis " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/regions22-hg38.bed \
         -o Cis-Expected/"+n+"_100kb.cis.tsv"
    cmd2 = "cooltools expected-cis " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/regions-long-hg38.bed \
         -o Cis-Expected/"+n+"_100kb_long.cis.tsv"
    cmd3 = "cooltools expected-cis " \
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/regions-short-hg38.bed \
         -o Cis-Expected/"+n+"_100kb_short.cis.tsv"

    print(n)
    #print(cmd1)
    os.system(cmd1)
    os.system(cmd2)
    os.system(cmd3)
    #print(cmd1,"\n",cmd2)
    print("Done\t",n,i)
    i=i+1

# %%
#gene EV cis arms
i=0
for fn in fls[:-1]:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools eigs-cis --phasing-track " \
        "/home/snehal/Downloads/DekkerLab/References/reftrack_100kb_human.tsv::gene_coverage "\
         +n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 --view ../Ozgun/hg38-arms22.tsv -o \
         EVcis-arms-100kb/"+n+"_100kb_arms --bigwig "
    print(cmd1)
    os.system(cmd1)
    i=i+1
    print(i,"Done")

# %%
#CT track generation
i=0
for n in fls[:-1]:
    #f = n.replace(".sampled.hg38.mapq_30.1000.mcool","")
    CT.create_Centromere_Telomere_vector(f,'EVcis-arms-100kb/',\
                                         '/home/snehal/Downloads/DekkerLab/References/Centromeres-hg38.tsv',\
                                         '100kb_arms','CTtracks/',False)
    i=i+1
    print(i,"Done\t",f)

# %%
# with trans expected all
i=0
for fn in fls[:1]:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools saddle "+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/"+n+"_100kb_arms.Cent.vecs.tsv::CT  Trans-Expected-arms/"+n+"_100kb.trans.tsv -o \
            CTobs_exp/"+n+"_hg38_all  --strength --fig pdf \
            --view ../Ozgun/hg38-arms22.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(cmd1)
    i=i+1
    print(i,"Done")

# %%
# with trans expected long
i=0
for fn in fls[:1]:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools saddle "+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/"+n+"_100kb_arms.longCent.vecs.tsv::CT  Trans-Expected-arms/"+n+"_100kb_long.trans.tsv -o \
            CTobs_exp/"+n+"_hg38_long  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-long.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    print(cmd1)
    #os.system(cmd1)
    i=i+1
    print(i,"Done")

# %%
# with trans expected short
i=0
for fn in fls[:-1]:
    #n = fn.replace(".sampled.hg38.mapq_30.1000.mcool","")
    cmd1 = "cooltools saddle "+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/"+n+"_100kb_arms.shortCent.vecs.tsv::CT  Trans-Expected-arms/"+n+"_100kb_short.trans.tsv -o \
            CTobs_exp/"+n+"_hg38_short  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-short.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(cmd1)
    i=i+1
    print(i,"Done")

# %%
#only observed
for f in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.Cent.vecs.tsv::CT  \
    Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb.trans.tsv\
    -o CTobs/"+f+"  --strength --fig pdf --view ../Ozgun/hg38-arms22.tsv -t trans --vrange 0 2"

    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.longCent.vecs.tsv::CT  \
    Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_long.trans.tsv\
    -o CTobs/"+f+"_long  --strength --fig pdf --view ../Ozgun/hg38-arms-long.tsv -t trans --vrange 0 2"

    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.shortCent.vecs.tsv::CT  \
    Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_short.trans.tsv\
    -o CTobs/"+f+"_short  --strength --fig pdf --view ../Ozgun/hg38-arms-short.tsv -t trans --vrange 0 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",f)

# %%
#only observed for cis (ran saddle_obs)
for f in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.Cent.vecs.tsv::CT  \
    Cis-Expected/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb.cis.tsv\
    -o CTobs_cis/"+f+"  --strength --fig pdf --view ../Ozgun/regions22-hg38.bed --vrange 0 2"

    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.longCent.vecs.tsv::CT  \
    Cis-Expected/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_long.cis.tsv\
    -o CTobs_cis/"+f+"_long  --strength --fig pdf --view ../Ozgun/regions-long-hg38.bed --vrange 0 2"

    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.shortCent.vecs.tsv::CT  \
    Cis-Expected/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_short.cis.tsv\
    -o CTobs_cis/"+f+"_short  --strength --fig pdf --view ../Ozgun/regions-short-hg38.bed --vrange 0 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",f)

# %%
#obs/expected of their own
i=0
for n in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.Cent.vecs.tsv::CT \
            Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb.trans.tsv -o \
            CTobs_exp/"+n+"_hg38_all  --strength --fig pdf \
            --view ../Ozgun/hg38-arms22.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.longCent.vecs.tsv::CT  \
            Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_long.trans.tsv -o \
            CTobs_exp/"+n+"_hg38_long  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-long.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.shortCent.vecs.tsv::CT  \
            Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_short.trans.tsv -o \
            CTobs_exp/"+n+"_hg38_short  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-short.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",n)

# %%
#obs/expected of WT-Ctrl-4-51-and-4-52-R1R2 control
i=0
for n in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.Cent.vecs.tsv::CT \
            Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb.trans.tsv -o \
            CTexp_cntrl/"+n+"_hg38_all  --strength --fig pdf \
            --view ../Ozgun/hg38-arms22.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.longCent.vecs.tsv::CT  \
            Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb_long.trans.tsv -o \
            CTexp_cntrl/"+n+"_hg38_long  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-long.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.shortCent.vecs.tsv::CT  \
            Trans-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb_short.trans.tsv -o \
            CTexp_cntrl/"+n+"_hg38_short  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-short.tsv -t trans --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",n)

# %% [markdown]
# ### Cis saddle

# %%
fls = ['BKO98-ATRA-5days-4-51-and-4-52-R1R2','BKO98-Ctrl-4-51-and-4-52-R1R2',
       'WT-ATRA-5days-4-51-and-4-52-R1R2','WT-Ctrl-4-51-and-4-52-R1R2']

# %%
#only observed
for f in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.Cent.vecs.tsv::CT  \
    Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb.cis.tsv\
    -o Cis/CTobs/"+f+"  --strength --fig pdf --view ../Ozgun/hg38-arms22.tsv --vrange 0 2"

    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.longCent.vecs.tsv::CT  \
    Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_long.cis.tsv\
    -o Cis/CTobs/"+f+"_long  --strength --fig pdf --view ../Ozgun/hg38-arms-long.tsv --vrange 0 2"

    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
    CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_arms.shortCent.vecs.tsv::CT  \
    Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+f+"_100kb_short.cis.tsv\
    -o Cis/CTobs/"+f+"_short  --strength --fig pdf --view ../Ozgun/hg38-arms-short.tsv --vrange 0 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",f)

# %%
#obs/expected of their own
i=0
for n in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.Cent.vecs.tsv::CT \
            Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb.cis.tsv -o \
            Cis/CTobs_exp/"+n+"_hg38_all  --strength --fig pdf \
            --view ../Ozgun/hg38-arms22.tsv --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.longCent.vecs.tsv::CT  \
            Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_long.cis.tsv -o \
            Cis/CTobs_exp/"+n+"_hg38_long  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-long.tsv --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.shortCent.vecs.tsv::CT  \
            Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_short.cis.tsv -o \
            Cis/CTobs_exp/"+n+"_hg38_short  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-short.tsv --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",n)

# %%
#obs/expected of WT-Ctrl-4-51-and-4-52-R1R2 control
i=0
for n in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.Cent.vecs.tsv::CT \
            Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb.cis.tsv -o \
            Cis/CTexp_cntrl/"+n+"_hg38_all  --strength --fig pdf \
            --view ../Ozgun/hg38-arms22.tsv --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.longCent.vecs.tsv::CT  \
            Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb_long.cis.tsv -o \
            Cis/CTexp_cntrl/"+n+"_hg38_long  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-long.tsv --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.shortCent.vecs.tsv::CT  \
            Cis-Expected-arms/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb_short.cis.tsv -o \
            Cis/CTexp_cntrl/"+n+"_hg38_short  --strength --fig pdf \
            --view ../Ozgun/hg38-arms-short.tsv --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",n)

# %%
# Cis saddles obs/expected of WT-Ctrl-4-51-and-4-52-R1R2 control
i=0
for n in fls:
    fl = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.Cent.vecs.tsv::CT \
            Cis-Expected/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb.cis.tsv -o \
            Cis/CTexp_cntrl/"+n+"_hg38_all  --strength --fig pdf \
            --view ../Ozgun/regions22-hg38.bed --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_long = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.longCent.vecs.tsv::CT  \
            Cis-Expected/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb_long.cis.tsv -o \
            Cis/CTexp_cntrl/"+n+"_hg38_long  --strength --fig pdf \
            --view ../Ozgun/regions-long-hg38.bed --vrange 0 2 \
            --vmin 0.5 --vmax 2"
    fl_short = "cooltools saddle GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+".sampled.hg38.mapq_30.1000.mcool::/resolutions/100000 \
            CTtracks/GSE252149_CA-HiC-Dpn-SH-SY5Y-"+n+"_100kb_arms.shortCent.vecs.tsv::CT  \
            Cis-Expected/GSE252149_CA-HiC-Dpn-SH-SY5Y-WT-Ctrl-4-51-and-4-52-R1R2_100kb_short.cis.tsv -o \
            Cis/CTexp_cntrl/"+n+"_hg38_short  --strength --fig pdf \
            --view ../Ozgun/regions-short-hg38.bed --vrange 0 2 \
            --vmin 0.5 --vmax 2"

    os.system(fl)
    os.system(fl_long)
    os.system(fl_short)
    print("Done:",n)
